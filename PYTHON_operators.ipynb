# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaysatyapal/python-basic-practice/blob/main/PYTHON_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PYTHON operators**
