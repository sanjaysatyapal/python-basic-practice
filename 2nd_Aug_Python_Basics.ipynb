# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaysatyapal/python-basic-practice/blob/main/2nd_Aug_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Intro to Python**

# %%
2
# Out:
# 2

# %%
'hi'
# Out:
# 'hi'

# %%
"hello"
# Out:
# 'hello'

# %%
print(2)
# Out:
# 2

# %%
print("hello world")
# Out:
# hello world

# %%
x=2

# %%
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
a=2
b=3
result=a+b
print(result)
# Out:
# 5

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
a=2
b=3
result=a+b
print(result)
# we are adding two number
# Out:
# 5

# %%
'''
this is
multipe line comment


'''

x=10
print(x)
# Out:
# 10

# %%
a=int(input("enter you first nunber"))
b=int(input("enter your seconf number"))
result=a+b
print(result)
# Out:
# enter you first nunber5
# enter your seconf number9
# 14

# %%
x=10

# %%
type(x)
# Out:
# int

# %%
y="hi"

# %%
type(y)
# Out:
# str

# %%
# calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
# Out:
# Enter first number: 12
# Enter second number: 2
# Addition: 14.0
# Subtraction: 10.0
# Multiplication: 24.0
# Division: 6.0

# %%
a=int(input("enter first number "))
b=int(input("enter second number "))
Addition=a+b
sub=a-b
multiplication=a*b
division=a/b
print(Addition)
print(sub)
print(multiplication)
print(division)
# Out:
# enter first number 3
# enter second number 6
# 9
# -3
# 18
# 0.5

# %% [markdown]
# # Python Operators

# %% [markdown]
# Operators are special that performs specific operations on one or more values
#
#
#
# 1. Artrimetic opeartors
# 2. relational operators
# 3. assignment operators
# 4. logical operators

# %% [markdown]
# **Artimetic opearators**

# %%
# add (+)

2+8
# Out:
# 10

# %%
# sub

8-3
# Out:
# 5

# %%
# mul

8*3
# Out:
# 24

# %%
# div
# here we will get quiotent

10/2
# Out:
# 5.0

# %%
# moduls %
# here we will get reminder

10%3
# Out:
# 1

# %% [markdown]
# **Relational Operators (comparison)**

# %% [markdown]
# here out is either true or value

# %%
# == (equal to)

a=10
b=10
print(a==b)
# Out:
# True

# %%
# != (not equal to)

a=10
b=5
a!=b
# Out:
# True

# %%
# > (greater than)

3>6
# Out:
# False

# %%
# < (lesser than)

1<3
# Out:
# True

# %% [markdown]
# **Assignment Operators**

# %%
# = (assign the value)

a=10

# %%
# += (add and assign)
#a= a+5
a=10
a +=5

print(a)
# Out:
# 15

# %%
# -= (sub and assign)
# a= a-2
a=12
a -=2
print(a)
# Out:
# 10

# %%
# *=, /=
# multiple and assign
# divide and assign

# %%
a=10
a *=2
print(a)
# Out:
# 20

# %% [markdown]
# **Logical operators**

# %%
# and (true if both conditions are true)
a=4
b=7
a>5 and b<10
# Out:
# False

# %%
# or (true if one is true, if both conditors are false u get false)

a=10
b=3

a>5 or b<3
# Out:
# True

# %%
# not
a=10
not(a>5)
# Out:
# False

# %% [markdown]
# **Membership opeartors**

# %%
# in

'p' in 'apple'
# Out:
# True

# %%
'A' in 'apple'
# Out:
# False

# %%
# not in

'a' not in 'apple'
# Out:
# False

# %% [markdown]
# # **Python Data Types**

# %% [markdown]
# **Number**

# %%
a=10
b=2.13
c=1+1j

# %%
type(a)
# Out:
# int

# %%
age = 25
year = 2025
population = 1400000000
students_count = 500
score = 95
temperature = 37
height_cm = 175
salary = 45000
distance_km = 10
items_in_cart = 8

# %%
type(b)
# Out:
# float

# %%
price = 19.99
height_m = 1.75
weight_kg = 68.5
temperature_c = 36.6
average_score = 87.5
interest_rate = 3.75
speed_kmph = 55.5
gpa = 3.9
discount = 12.5
pi_value = 3.1416

# %%
c=2+2j

# %%
type(c)
# Out:
# complex

# %% [markdown]
# **Boolean**

# %%
a=True
b=False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %% [markdown]
# **set**

# %%
a={,2,4,"hi",3.14}

# %%
type(a)
# Out:
# set

# %% [markdown]
# **Dict**

# %%
student = {"name": "Alice", "age": 20}
book = {"title": "Python 101", "author": "John"}
employee = {"id": 101, "salary": 50000}
car = {"brand": "Toyota", "year": 2022}
product = {"name": "Laptop", "price": 75000}
account = {"username": "user123", "active": True}
order = {"order_id": 5001, "status": "Shipped"}
profile = {"email": "user@example.com", "verified": False}
movie = {"title": "Inception", "rating": 8.8}
course = {"name": "Data Science", "duration": "3 months"}

# %%
names={'name':'ravi','age':23}

# %%
type(names)
# Out:
# dict

# %% [markdown]
# **string**

# %%
x="hello"

# %%
type(x)
# Out:
# str

# %% [markdown]
# **List**

# %% [markdown]
# The python list is orders collection of elements. list can contain int,float,string

# %%
fruits = ["apple", "banana", "cherry"]
marks = [85, 90, 75]
shopping_cart = ["book", "pen", "notebook"]
temperatures = [36.5, 37.0, 38.2]
colors = ["red", "green", "blue"]
cities = ["Delhi", "Tokyo", "Paris"]
scores = [10, 20, 15]
grades = ["A", "B", "C"]
ids = [101, 102, 103]
expenses = [2500, 1500, 3000]

# %%
l=[1,2,3,4,4.5,True,"hi"]

# %%
type(l)
# Out:
# list

# %% [markdown]
# **Tuple**

# %%
coordinates = (10, 20)
date = (2025, 7, 4)
size = (1920, 1080)
color_rgb = (255, 0, 0)
version = (1, 0, 5)
point3d = (3, 5, 7)
dimensions = (10.5, 20.3)
birthday = ("July", 4, 1995)
book_info = ("Python Basics", "John", 2022)
address = ("221B", "Baker Street", "London")

# %%
t=(1,2,3,4,6.7,True)

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# **Mutable and Immutable**

# %%
x=[1,2,3,4,50]

# %%
x[0]
# Out:
# 1

# %%
x[1]
# Out:
# 2

# %%
l=['A','B','C']

# %%
l[2]
# Out:
# 'C'

# %%
x=[1,2,3,4,50]

# %%
x[4] = 5

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
l=['A','B','C']

# %%
l[2]="pw"

# %%
l
# Out:
# ['A', 'B', 'pw']

# %%
book_info = ("Python Basics", "John", 2022)

# %%
#book_info[1]="ravi"

# %%
x="pwhi"

# %%
#x[1]='k'

# %%
student = {"name": "Alice", "age": 20}

# %%
type(student)
# Out:
# dict

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 20)])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.values()
# Out:
# dict_values(['Alice', 20])

# %%
student['name']
# Out:
# 'Alice'

# %%
student['age'] = 30

# %%
student
# Out:
# {'name': 'Alice', 'age': 30}

# %%
student = {"name": "Alice", "age": 20}

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 20)])

# %%
student.values()
# Out:
# dict_values(['Alice', 20])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student['name']
# Out:
# 'Alice'

# %%
student['age'] = 30

# %%
student
# Out:
# {'name': 'Alice', 'age': 30}

# %%
student['name']='ravi'

# %%
student
# Out:
# {'name': 'ravi', 'age': 30}

# %%
student.update({
    "age":26,
    "course":"python"
})

# %%
student
# Out:
# {'name': 'ravi', 'age': 26, 'course': 'python'}

# %%
age={12,12,12,13}

# %%
type(age)
# Out:
# set

# %%
age
# Out:
# {12, 13}
