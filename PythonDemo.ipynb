# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaysatyapal/python-basic-practice/blob/main/PythonDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
20+90
# Out:
# 110

# %%
print("Hi am a data analyst")
# Out:
# Hi am a data analyst

# %%
print ('I am looking for MIS Executive role for starting my carrer in data analytics')
# Out:
# I am looking for MIS Executive role for starting my carrer in data analytics

# %%
x = 'sanjay data analyst'
print (x)
# Out:
# sanjay data analyst

# %%
name = "sanjay"

name

print (name)
# Out:
# sanjay

# %%
#length of rectangle l*b

l = 10
b = 20
area = l*b
print ("This is the length of rectangle:",area)
# Out:
# This is the length of rectangle: 200

# %%
# calculate area of circle

radius = 5
pi = 3.14159
area = pi * radius * radius
print (area)
print ("Area of the circle:", area)
# Out:
# 78.53975
# Area of the circle: 78.53975

# %%
# calculate are of triangle

# Area of Triangle

base = 10
height = 5

area = 0.5 * base * height

print("This is the area of triangle:",area)
# Out:
# This is the area of triangle: 25.0

# %%
help ("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# When we create variable so we need to remember this.
#
# 1. Letters allowed (A-Z, a-z)
# 2. Numbers (0-9)
# 3. Underscore (_)
#
# Not allowed
#
# 1.$
# 2 .
# 3 space
# 4 @
# 5 %
# 6 &
# 7 Keywords

# %% [markdown]
# Variable

# %%
height = 1.79
weight = 68.7
BMI = weight / height ** 2
print (BMI)
# Out:
# 21.44127836209856

# %%
input1 = input ("Enter input 1")
input2 = input ("Enter input 2")
result = input1+input2
print(result)
# Out:
# Enter input 1Data
# Enter input 2Analyst
# DataAnalyst

# %%
x = 14

type(x)
# Out:
# int

# %%
x = input('enter a number')
type (x)
# Out:
# enter a number1
# str

# %%
x =int (input('enter a number'))
type (x)
# Out:
# enter a number12
# int

# %%
# Calculate area of traingle using (input and int) functions

l = int(input("length"))
w = int(input("width"))
area = l * w
print ("Area of rectangle=", area)
# Out:
# length10
# width30
# Area of rectangle= 300

# %%
# calculate area of circle using (input and int) functions

radius = int(input("this is radius"))
pi = float(input("this is pi"))
area = pi * radius * radius
print ("Area of the circle:", area)
# Out:
# this is radius10
# this is pi3.908
# Area of the circle: 390.79999999999995
